# %% [markdown]
# ## STEP 1:- Extraction data from pdf

# %%
# pip install pdfplumber
import pdfplumber

pdf = pdfplumber.open("../../panalinks/J8.pdf")  #5610112MJ2
n = len(pdf.pages)

# ***for all pages text
text = ""
for page in range(n):
    data = pdf.pages[page].extract_text()
    text = (text + data).strip()
#     text = str(text + data).replace('\n',' ')
    
# print("Whole document data : {}".format(text))



# ***for first 5 page text
text3 = ""
for page in range(0,2):
    data3 = pdf.pages[page].extract_text()
    text3 = (text3 + data3).strip()
    
# print("Whole document data : {}".format(text3))
   
    
    
# ***for last page text
text2 = ""
for page in range(n-1,n):
    data2 = pdf.pages[page].extract_text()
    text2 = (text2 + data2).strip()
    
print("Whole document data : {}".format(text2))
   
    
    
pdf.close()


# file1=open(r"J1.txt","w", encoding='utf-8')
# file1.writelines(text)

# print(file1.read())
# file1.close()


# with open('../../panalinks/J1.pdf', 'r',encoding="cp437", errors='ignore', newline='') as G:
#     print(G.read())
    
# open('filename.csv', encoding="cp437", errors='ignore')
# open(file_name, 'w', newline='', encoding="cp437", errors='ignore')
# Out:
# Whole document data : be, it may turn out to be good if those who are called to
# work  it,  happen  to  be  a  good  lot.  The  working  of  a
# Constitution does not depend wholly upon the nature of
# the Constitution. The Constitution can provide only the
# organs of State such as the Legislature, the Executive and
# the Judiciary. The factors on which the working of those
# organs of the State depend are the people and the political
# parties they will set up as their instruments to carry out
# their wishes and their politics. "
#
# One can only hope that keeping these thoughts in mind a system is
# developed  which  ensures  selection  of  people  having  impeccable
# integrity,  who  are  totally  independent,  have  a  good  character  and
# reputation,  are  free  from  influence  or  pressure,  and  have  requisite
# experience  in  the  jurisdictions  they  would  deal  with  as
# Chairpersons/Members of Tribunals.
#
# …………………………..J.
# (Deepak Gupta)
#
#
# New Delhi
# ...

# %% [markdown]
# ## STEP 2:- Extracting specific Information using  Regular Expressions

# %%
#1. For checking Reportable or Non-Reportabe file

import re

def checkReportable():
      
    if re.search("Non.*Reportable|NONREPORTABLE|NON.*REPORTABLE", text):
        return "Non-Reportable Judgmental Pdf file"
    elif re.search("Reportable|REPORTABLE|reportable", text):
        return "Reportable Judgmental Pdf file"    
    else:
        return "Can't Pridict"
    
checkReportable = checkReportable()

# %%
#2. For checK THE followings

# CRIMINAL APPELLATE JURISDICTION
# CIVIL APPELLATE JURISDICTION
# CIVIL ORIGINAL JURISDICTION
# CIVIL APPELLATE/ORIGINAL JURISDICTION 
# CIVIL/CRIMINAL ORIGINAL JURISDICTION

def checkJURISDICTION():
      
    if re.search("CRIMINAL APPELLATE JURISDICTION", text):
        return("CRIMINAL APPELLATE JURISDICTION")
    elif re.search("CIVIL APPELLATE JURISDICTION", text):
        return("CIVIL APPELLATE JURISDICTION")
    elif re.search("CIVIL ORIGINAL JURISDICTION", text):
        return("CIVIL ORIGINAL JURISDICTION")  
    elif re.search("CIVIL APPELLATE/ORIGINAL JURISDICTION", text):
        return("Both CIVIL APPELLATE/ORIGINAL JURISDICTION ")
    elif re.search("CIVIL/CRIMINAL ORIGINAL JURISDICTION", text):
        return("Both CIVIL/CRIMINAL ORIGINAL JURISDICTION ")      
    else:
        return("Can't Pridict")
    
checkJURISDICTION = checkJURISDICTION()
# checkJURISDICTION

# %%
def get_pattern_match(pattern, text):
    matches = re.search(pattern, text)
    if matches:
        return matches[0]
    else:
        return ''
    
# def get_pattern_findall(pattern, text):
#     matches = re.findall(pattern, text)
#     if matches:
#         return matches[0]   

# CheckJURISDICTION = get_pattern_match('CRIMINAL APPELLATE JURISDICTION|CIVIL APPELLATE JURISDICTION|CIVIL ORIGINAL JURISDICTION|CIVIL APPELLATE/ORIGINAL JURISDICTION|CIVIL/CRIMINAL ORIGINAL JURISDICTION', text)
# # CheckJURISDICTION

appliant = get_pattern_match('\n[\w\W]{1,55}(Appellant|APPELLANT|PETITIONER|Petitioner)', text).replace('\n','',5) #.strip('….PETITIONER|.....APPELLANT')
# appliant = re.sub('','',appliant) 

respondent = get_pattern_match('V\w{5,7}[\w\W]{1,110}(RESPONDENT|Respondent)', text).strip('Versus….|….Respondent|VERSUS|…RESPONDENT').replace('\n','',5)
# appliant = re.sub('','',appliant) 
# respondent

# TillJudgment = get_pattern_match('[(\w\W)]*(J U D G M E N T|O R D E R)', text)
# TillJudgment
# Civil_Appeal_No = get_pattern_match('C\w{4,7} A\w{4,5} \w.{1,3}[\w\W]{1,26}\d', text)
# Civil_Appeal_No

# Arising_out_of_SLP = get_pattern_match('[A-a]\w{5,6} [oO][A-Za-z]{2,3} [ofOF][\w\W]{1,15} [noNONo][\w\W]{1,23}\d', text)
# Arising_out_of_SLP

# %%
#3. For checking Civil Appeal No

def Search_text(text,regex):
    """
    Extract the string that matches the regular expressions
    param:
        text - text string extracted from pdf file
        
        regex - reguar expressions that is to be searched for
    returns the searched string
    """
    required_info=''
    ResSearch = re.search(regex, text)
    if ResSearch:
        required_info = ResSearch.group()
    return required_info

# Search_text(text,'\n[\w\W]{1,55}(Appellant|APPELLANT)|\s[\w\S .]{1,200}(PETITIONER|Petitioner)').strip(' ….PETITIONER').replace('\n','',3)
# Search_text(text,'V\w{5,7}[\w\W]{1,110}(RESPONDENT|Respondent)').strip('Versus….|….Respondent|VERSUS|…RESPONDENT').replace('\n','',5)

# %% [markdown]
# #### Define the regex for each and every field from the text which needs to be extracted. For Testing the regular expression use https://pythex.org/. Copy and paste your texts in Your test string field
# #### You can read more about regular expressions at https://docs.python.org/3/howto/regex.html

# %%
#*** REGULAR EXPRESSION VARIBALES *****

regex_Civil_Appeal_No = 'C\w{4,7} A\w{4,5} \w.{1,3}[\w\W]{1,26}\d'  #C\w{1,7} A\w{1,5} \w.{1,5}([A-Za-z0-9 ]){1,15}

regex_No = '[\d-]{2,12}|\d{2,6}'
regex_Date = 'of \d{1,4}|OF \d{3,4}|/\d{3,4}' #20[0-9]{2}|19[0-9]{2}|


regex_writ_petition = 'W\w{1,5} P\w{7,8}\n[\w\W]{1,23}\d|W\w{1,5} P\w{7,8} [noNoNO][\w\W]{1,23}\d|W.P.[\w\W]{1,15}[noNoNO][\w\W]{1,20}\d|W\w{1,5} P\w{7,8}[\w\W]{1,10} [noNoNO][\w\W]{1,23}\d'
regex_REVIEW_petition = 'R\w{3,5} P\w{7,8} [(\w. /)]{1,30}\d'

regex_Arising_out_of_SLP = '[A-a]\w{5,6} [oO][A-Za-z]{2,3} [ofOF][\w\W]{1,15} [noNONo][\w\W]{1,23}\d' #[A-a]\w{5,6} [oO][A-Za-z]{2,3} [ofOF][\w\W]{1,50}\d


regex_Applicant='[\W\w]{55}V([a-zA-Z]){5,6}|[\W\w]{1,37}Appellant|[.\s&\w]*Appellant|[(. \w)]*  …?A'
regex_Respondent='V\w{5,7}[\W\w]{1,100}W.{5,8}|V\w{5,6}[\W\w]{1,100}Respondent'


regex_judgment= '[(\w\W)]*(J U D G M E N T|O R D E R)' #[\W\w]*


regex_Judge='J U D G M E N T[\W\w]{5,20}\s' 
all_judge = 'J\W+\(.*?\)|J.\s[\w\W]{5,20}\n|\[.*?\]'
Rdate = '[a-zA-Z]{4,10} [\d,.]{2,4}[ \d,.]{2,6}\d'

# %%
#*** MAKING FUNCTIONS OBJECTS*****

Civil_Appeal_No = Search_text(text,regex_Civil_Appeal_No)
No= Search_text(text,regex_No)
Date = Search_text(text,regex_Date).strip('of OF')

writ_petition =  Search_text(text,regex_writ_petition)
REVIEW_petition = Search_text(text,regex_REVIEW_petition)
Arising_out_of_SLP=Search_text(text,regex_Arising_out_of_SLP)

Applicant= Search_text(text,regex_Applicant)
Respondent= Search_text(text,regex_Respondent)

TillJudgment = Search_text(text,regex_judgment)

Judge= Search_text(text,regex_Judge)
date= Search_text(text2,Rdate)

# %%
# Findding all function

def findall_CAN():
    match1 = re.findall(regex_Civil_Appeal_No, text)
    return match1
findall_CAN = findall_CAN()


def findall_AOS():
    match2 = re.findall(regex_Arising_out_of_SLP, text)
    return match2
findall_AOS = findall_AOS()


def findall_WP():
    match3 = re.findall(regex_writ_petition, text)
    return match3
findall_WP = findall_WP()

def findall_RP():
    match3 = re.findall(regex_REVIEW_petition, text)
    return match3
findall_RP = findall_RP()

def findall_Judge():
    match3 = re.findall(all_judge, text2)
    return match3
findall_Judge = findall_Judge()




######################################################################

def Findall(pattern, text):
    matches = re.findall(pattern, text)
    if matches:
        return matches[0]
    
# CAN = Findall(CAN,text).strip('Civil Appeal No.CIVIL APPEAL NO.')
# CAND = Findall(CAND,text).strip('of OF')
# AOSN = Findall(AOSN,text).strip('Arising out of SLP') 
# AOSND = Findall(AOSND,text).strip('Arising out of SLP') 

def searchPattern(regx, text): 
    for line in re.findall(regx, text):
        return line
    else:
        return ''

CAN = searchPattern(regex_No,Civil_Appeal_No)
CAD = searchPattern(regex_Date,Civil_Appeal_No).replace('of','').replace('OF','').replace('Of','')

AOSN = searchPattern(regex_No,Arising_out_of_SLP)
AOSD = searchPattern(regex_Date,Arising_out_of_SLP).replace('of','').replace('OF','').replace('Of','')

WPN = searchPattern(regex_No,writ_petition)
WPD = searchPattern(regex_Date,writ_petition).replace('of','').replace('OF','').replace('Of','').replace('/','')

RPN = searchPattern(regex_No,REVIEW_petition)
RPD = searchPattern(regex_Date,REVIEW_petition).replace('of','').replace('OF','').replace('Of','').replace('/','')

# %% [markdown]
# ##  START CALLING FUNCTIONS

# %%
checkReportable
# Out:
# 'Reportable Judgmental Pdf file'

# %%
# CheckJURISDICTION
checkJURISDICTION
# Out:
# 'Both CIVIL APPELLATE/ORIGINAL JURISDICTION '

# %%
# Applicant
appliant
# Out:
# 'Rojer Mathew  …Appellant'

# %%
# Respondent
respondent
# Out:
# ' South Indian Bank Ltd. & Ors.    … '

# %%
Civil_Appeal_No
# Out:
# 'Civil Appeal No. 8588 of 2019'

# %%
CAN
# No
# Out:
# '8588'

# %%
CAD
# Date
# Out:
# ' 2019'

# %%
findall_CAN
# Out:
# ['Civil Appeal No. 8588 of 2019',
#  'CIVIL APPEAL NO   8588  OF 2019',
#  'CIVIL APPEAL NO.8588 OF 2019']

# %%
Arising_out_of_SLP
# Out:
# 'Arising out of SLP (C) No 15804 of 2017'

# %%
AOSN
# Out:
# '15804'

# %%
AOSD
# Out:
# ' 2017'

# %%
findall_AOS
# Out:
# ['Arising out of SLP (C) No 15804 of 2017']

# %%
REVIEW_petition
# Out:
# ''

# %%
RPN
# Out:
# ''

# %%
RPD
# Out:
# ''

# %%
findall_RP

# all = re.findall(regex_No,str(findall_RP))

# rpNo= []
# rpDate = []
# for i in range(0, len(all)):
#     if i % 2:
#         rpDate.append(all[i])
#     else :
#         rpNo.append(all[i])
# # res = odd_i + even_i
# # rpNo 
# rpDate
# Out:
# []

# %%
writ_petition.replace('\n',' ')
# Out:
# 'W.P.(C) No.267/2012'

# %%
WPN
# Out:
# '267'

# %%
WPD
# Out:
# '2012'

# %%
findall_WP
# Out:
# ['W.P.(C) No.267/2012',
#  'W.P.(C) No. 279/2017',
#  'W.P.(C) No. 558/2017',
#  'W.P.(C) No.\n561/2017',
#  'W.P.(C) No. 625/2017',
#  'W.P.(C) No. 640/2017',
#  'W.P.(C) No. 1016/2017',
#  'W.P.(C) No. 788/2017',
#  'W.P.(C) No. 925/2017',
#  'W.P.(C) No. 1098/2017',
#  'W.P.(C)\nNo.  1129/2017',
#  'W.P.(C)  No.  33/2018',
#  'W.P.(C)  No.  205/2018',
#  'W.P.(C)  No.\n467/2018',
#  'Writ Petition (Civil) No. 267 of\n2012',
#  'Writ Petition (Civil) No. 279/2017',
#  'W.P. (C) No. 267/2012',
#  'Writ Petition (Civil) No. 267 of 2012',
#  'Writ Petition (C) No 279 of 2017',
#  'Writ Petition (C) No 558 of 2017',
#  'Writ Petition (C) No 561 of 2017',
#  'Writ Petition (C) No 625 of 2017',
#  'Writ Petition (C) No 640 of 2017 \n \n1',
#  'Writ Petition (C) No 1016 of 2017',
#  'Writ Petition (C) No 788 of 2017',
#  'Writ Petition (C) No 925 of 2017',
#  'Writ Petition (C) No 1098 of 2017',
#  'Writ Petition (C) No 1129 of 2017',
#  'Writ Petition (C) No 33 of 2018',
# ...

# %%
TillJudgment = TillJudgment.replace('\n', '', 1000)
TillJudgment
# Out:
# 'REPORTABLE IN THE SUPREME COURT OF INDIA CIVIL APPELLATE/ORIGINAL JURISDICTION Civil Appeal No. 8588 of 2019 [Arising out of Special Leave Petition (Civil) No.15804 of 2017] Rojer Mathew  …Appellant(S) VERSUS South Indian Bank Ltd. & Ors.    … Respondent(S) WITH W.P.(C) No.267/2012, W.P.(C) No. 279/2017, W.P.(C) No. 558/2017, W.P.(C) No.561/2017, W.P.(C) No. 625/2017, W.P.(C) No. 640/2017, W.P.(C) No. 1016/2017,W.P.(C) No. 788/2017, W.P.(C) No. 925/2017, W.P.(C) No. 1098/2017, W.P.(C)No.  1129/2017,  W.P.(C)  No.  33/2018,  W.P.(C)  No.  205/2018,  W.P.(C)  No.467/2018, T.C.(C) No. 49/2018, T.C.(C) No. 51/2018, T.P.(C) No. 2199/2018J U D G M E N T RANJAN GOGOI, CJI 1. Leave granted.BRIEF BACKGROUND: 2. In the present batch of cases, the constitutionality of Part XIV of the FinanceAct, 2017 and of the rules framed in consonance has been assailed.  While it would be repetitious to reproduce the pleadings of each case separately, a brief reference is  being  made,  illustratively,  to 
# ...

# %%
judg = Judge.replace('\n','',5).strip('J U D G M E N T')
judg
# Out:
# 'RANJAN GOGOI, CJI'

# %%
findall_Judge
allJudge = []
for x in findall_Judge:
    allJudge.append(x.replace("\n", "").strip('J.[]() '))
    
allJudge
# Out:
# ['Deepak Gupta']

# %%
date
# Out:
# 'November 13,  2019'

# %% [markdown]
# ## STEP 3:-  Reformat and Export  (Convert the data into a pandas dataframe OR json format)

# %%
import pandas as pd # Data manipulation library

## Creating a dataframe
df_details = pd.DataFrame(columns=['checkReportable','checkJURISDICTION','Appliant','Respondent','Civil Appeal No','CAN','CAND','filndall_CAN','Arising_out_of_SLP','AOSN','AOSD','filndall_AOS','writ_petition','WPN','WPD','filndall_WP','REVIEW_petition','RPN','RPD','Till J U D G M E N T', 'JUDGE','All Judge','Date'])

data=[checkReportable,checkJURISDICTION,appliant,respondent,Civil_Appeal_No,CAN,CAD,findall_CAN,Arising_out_of_SLP,AOSN,AOSD,findall_AOS,writ_petition,WPN,WPD,findall_WP,REVIEW_petition,RPN,RPD,TillJudgment,judg,allJudge,date]

## Inserting the row
df_details.loc[len(df_details.index)] = data

df_details
# Out:
#                   checkReportable  \
# 0  Reportable Judgmental Pdf file
#
#                              checkJURISDICTION                  Appliant  \
# 0  Both CIVIL APPELLATE/ORIGINAL JURISDICTION   Rojer Mathew  …Appellant
#
#                              Respondent                Civil Appeal No   CAN  \
# 0   South Indian Bank Ltd. & Ors.    …   Civil Appeal No. 8588 of 2019  8588
#
#     CAND                                       filndall_CAN  \
# 0   2019  [Civil Appeal No. 8588 of 2019, CIVIL APPEAL N...
#
#                         Arising_out_of_SLP   AOSN  ...  WPN   WPD  \
# 0  Arising out of SLP (C) No 15804 of 2017  15804  ...  267  2012
#
#                                          filndall_WP REVIEW_petition RPN RPD  \
# 0  [W.P.(C) No.267/2012, W.P.(C) No. 279/2017, W....
#
#                                 Till J U D G M E N T              JUDGE  \
# 0  REPORTABLE IN THE SUPREME COURT OF INDIA CIVIL...  RANJAN GOGOI, CJI
#
#         All Judge                Date
# ...

# %%
#export
df_details.to_csv("J8.csv",index=False)

# %%
# import json 

# data = {}

# data = {
    
#     "checkReportable":checkReportable,
#     "checkJURISDICTION":checkJURISDICTION,
#     'appliant':appliant,
#     'respondent':respondent,
#     'Civil Appeal No':Civil_Appeal_No,
# #     'findall_CAN':filndall_CAN,
#     CAN:CAD,
#     'Arising_out_of_SLP':Arising_out_of_SLP,
#     AOSN:AOSD,
# #     'filndall_AOS':filndall_AOS,
#     'writ_petition':writ_petition,
#     WPN:WPD,
# #     'filndall_WP':filndall_WP,
#     RPN:RPD,
# #     'Till J U D G M E N T':TillJudgment
    
# }
# # print(json.dumps(data,indent = 6, sort_keys = True))
# # with open('data.json', 'w') as f:
# #     print(json.dump(data, f, indent = 3, sort_keys = True))

# %% [markdown]
# # -------------------------END-----------------------------------

# %%
# https://tecoholic.github.io/ner-annotator/

import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    else:
        print("No entities found!!!")

# %%
# doc = nlp(u"Hi, How are you?")
# doc = nlp(u"may i go to New York, next May to see Statue Of Liberty")
# doc = nlp(u"Can I please have 500 dollar for Microsft Stocks")
# doc = nlp(u"Tesla to build a U.K factory for $6 million")
doc = nlp(text)

# %%
# show_ents(doc)

# %%
displacy.render(doc, style = "ent", minify= True, jupyter = True)

# %%
from spacy.tokens import Span

# %%
ORG = doc.vocab.strings[u"ORG"]
ORG

# %%
new_ent = Span(doc, 0,1,label = ORG)

# %%
doc.ents = list(doc.ents)+[new_ent]
show_ents(doc)

# %%
## Working with PDFs using pdfplumber and pypdf2
#

## Installations
# pip install PyPDF2
# pip install pdfplumber

## Requirements
#
import PyPDF2
import pdfplumber

def meta_data():
    pdf = pdfplumber.open("../../panalinks/J3.pdf")

    print("Number of pages : {}".format(len(pdf.pages)))
    print("Pages : {}".format(pdf.pages))

    print("Document Information")
    print(pdf.metadata)

    print("Author name : {}".format(pdf.metadata["Author"]))
    print("Creator : {}".format(pdf.metadata["Creator"]))

    pdf.close()

def extract_first():
    pdf = pdfplumber.open("../../panalinks/J3.pdf")
    page = pdf.pages[0]
    text = page.extract_text()

    print("First page data : {}".format(text))
    pdf.close()

def extract_whole():
    pdf = pdfplumber.open("../../panalinks/J3.pdf")
    n = len(pdf.pages)

    final = ""
    for page in range(n):
        data = pdf.pages[page].extract_text()
        final = final + "\n" + data
    
    print("Whole document data : {}".format(final))

    pdf.close()

def rotation_check():
    pdf = pdfplumber.open("../../panalinks/J3.pdf")
    l = int(pdf.pages[0].rotation)

    if(l):
        print("Page is rotated by : {}".format(l))
    else:
        print("Page is not rotated")
    
    # Using PyPDF2

    pdf_obj = open("../../panalinks/J3.pdf", 'rb')
    pdf_read_obj = PyPDF2.PdfFileReader(pdf_obj)
    pdf_read_page_rotation = pdf_read_obj.getPage(0).get("/Rotate")

    if(pdf_read_page_rotation == None):
        print("This page is not rotated")
    else:
        print("Page is rotated bye : {}".format(pdf_read_page_rotation))
    
def rotate_back():
    pdf_obj = open("Rotated_CV.pdf", 'rb')
    pdf_read_obj = PyPDF2.PdfFileReader(pdf_obj)
    n_pages = pdf_read_obj.getNumPages()
    for n in range(n_pages):
        pdf_read_page_rotation = pdf_read_obj.getPage(n).get("/Rotate")
        pdf_read_page_rotation = int(pdf_read_page_rotation)

        if(pdf_read_page_rotation):
            pdf_read_page_obj = pdf_read_obj.getPage(n)
            pdf_read_page_obj.rotateCounterClockwise(pdf_read_page_rotation)

            pdfwritter = PyPDF2.PdfFileWriter()
            pdfwritter.addPage(pdf_read_page_obj)

            pdf_obj1 = open("Rotated_CV1.pdf", "wb")
            pdfwritter.write(pdf_obj1)
            pdf_obj.close()
            pdf_obj1.close()

def merger():
    file_names = ["Rotated_J3.pdf", "Rotated_CV1.pdf"]
    merger = PyPDF2.PdfFileMerger()

    for pdf in file_names:
        with open(pdf, "rb") as file:
            merger.append(pdf)

    with open("merger.pdf", "wb") as f:
        merger.write(f)
    
    print("Merger done")

def splitter():
    with open('merger.pdf', 'rb') as file:
        reader = PyPDF2.PdfFileReader(file)
        n = reader.getNumPages()

        for page in range(n):
            writter = PyPDF2.PdfFileWriter()
            writter.addPage(reader.getPage(page))

            op_file = "split_{}.pdf".format(page)
            print("Splitted : {}".format(op_file))

            with open(op_file, 'wb') as f:
                writter.write(f)
        
        print("Splitting done")

if(__name__ == "__main__"):
#     meta_data()
#     extract_first()
#     extract_whole()
#     rotation_check()
#     rotate_back()
#     merger()
#     splitter()

## End

# %%
import re


my_str=  """ REPORTABLE
IN THE SUPREME COURT OF INDIA
CIVIL APPELLATE JURISDICTION
CIVIL APPEAL NO. 1586 OF 2004
M/s. P. Dasaratharama Reddy Complex   … Appellant
versus
Government of Karnataka and another           … Respondents
WITH
CIVIL APPEAL NO. 1587 OF 2004
CIVIL APPEAL NO. 1588 OF 2004
CIVIL APPEAL NO. 4187 OF 2004
CIVIL APPEAL NO. 5496 OF 2004
CIVIL APPEAL NO. 6323 OF 2004
CIVIL APPEAL NO. 6327 OF 2004
CIVIL APPEAL NO. 6328 OF 2004
CIVIL APPEAL NOS. 558-560 OF 2006
CIVIL APPEAL NO. 1374 OF 2013
CIVIL APPEAL NO. 9459  OF 2013
(arising out of SLP(C) No. 16117 OF 2004)
CIVIL APPEAL NO.9460  OF 2013
 (arising out of SLP(C) No. 17147 OF 2004)
mechanism and the same cannot be treated as an arbitration clause. He pointed 
out that Clause 29 and similar clauses contained in other agreements neither 
postulate hearing of the parties by the Chief Engineer nor he can adjudicate the 
dispute.   Shri Nath pointed out that the relevant clauses in the agreements 
entered into between the parties provide for settlement of disputes through Court 
6
Page 6
and, therefore, the decision, if any, taken by the Chief Engineer cannot be treated 
as an award of the Arbitrator.
10. We have considered  the respective  submissions.  Clause  29 of  the 
Agreement entered into between the parties (the appellant and the respondents in 
Civil Appeal No.1586/2004) and majority of other cases read as under:
“Clause-29: (a) If any dispute or difference of any kind whatsoever were to arise 
between the Executive Engineer/Superintending Engineer and the Contractor 
regarding the following matters namely,
(i) The meaning of the specifications designs, drawings and instructions 
herein before mentioned;
(ii)  The quality of workmanship or material used on the work and
(iii) Any other questions, claim right, matter, thing, whatsoever, in any way 
arising out of or relating to the   contract designs, drawings, specifications 
estimates, instructions, or orders, or those conditions or failure to execute the 
same whether arising during the progress of' the work, or after the completion, 
termination or abandonment thereof, the dispute shall, in the first place, be 
referred to the Chief Engineer who has jurisdiction over the work specified in 
the contract. The Chief Engineer shall within a period of ninety days from the 
date of being requested by the Contractor to do so, given written notice of his 
decision to the contractor.
Chief Engineer's decision final
(b) Subject   to   other   form   of   settlement   hereafter   provided,   the   Chief 
Engineer's decision in respect of every dispute or difference so referred shall be 
final and binding upon the Contractor. The said decision shall forthwith be given 
effect to and contractor shall proceed with the execution of the work with all due 
diligence.
Remedy when Chief Engineer's decision is not acceptable to Contract
(c) In case the decision of the Chief Engineer is not acceptable to the 
contractor, he may approach the Law Courts at for settlement of dispute after 
giving due written notice in this regard to the Chief Engineer within a period of 
7
Page 7 """

import re
# p = re.compile("C\w{4} A\w{5} \w{2,5}. \d{3,6}")
# p = "C\w{4} A\w{5} \w{2,5}. \d{3,6}"
p = re.compile("[(\s\S)]*J U D G M E N T")
# print(p.findall(my_str))



# for p in re.finditer((text)): 
#     print(p.findall()) 

# match = re.findall(p, final)
# print(match)

# import pandas as pd
# s = pd.Series(text)
# # print(s.str.findall(p))




# import re
# def match_text(text):
#        pattern = '[(\s\S)]*J U D G M E N T'
#        if re.search(pattern,  text):    #search for pattern in txt_data
#            return 'Match found'
#        else:
#            return('Match not found')
# print(match_text)         #prints Match not found

# %%
# import re

# def Search_text(text,regex):
#     required_info=''
#     ResSearch = re.search(regex, text)
#     if ResSearch:
#         required_info = ResSearch.group()
#     return required_info

# regex_Civil_Appeal_No = "Non..Reportable"
# Civil_Appeal_No = Search_text(text,regex_Civil_Appeal_No)
# Civil_Appeal_No 




### ---------For Testing purpose0--------------

# import re
# c = "C\w{4} A\w{5} \w{2,5}. \d{3,6}"
# j = ("[(\s\S)]*J U D G M E N T")
# j = re.compile("[(\s\S)]*J U D G M E N T")
# print(p.findall(my_str))

# match = re.findall(j, text)
# # print(match)

# def filndall(text,regex):
#     match = re.findall(regex, text)
#     return match
# filndall(text,c)
